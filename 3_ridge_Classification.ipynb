# %%
rs = 1234 
import pandas as pd
import pickle
import statsmodels.api as sm
import numpy as np
from tqdm.notebook import tqdm
tqdm.pandas()

df = pd.read_csv('new_cleaned_data.csv')
df.head()
# Out:
#   loan_limit             gender approv_in_adv loan_type loan_purpose  \
# 0         cf  Sex Not Available         nopre     type1           p1
# 1         cf               Male         nopre     type2           p1
# 2         cf               Male           pre     type1           p1
# 3         cf               Male         nopre     type1           p4
# 4         cf              Joint           pre     type1           p1
#
#   credit_worthiness open_credit business_or_commercial  loan_amount   term  \
# 0                l1        nopc                  nob/c       116500  360.0
# 1                l1        nopc                    b/c       206500  360.0
# 2                l1        nopc                  nob/c       406500  360.0
# 3                l1        nopc                  nob/c       456500  360.0
# 4                l1        nopc                  nob/c       696500  360.0
#
#    ... credit_type credit_score co-applicant_credit_type    age  \
# 0  ...         EXP          758                      CIB  25-34
# 1  ...        EQUI          552                      EXP  55-64
# 2  ...         EXP          834                      CIB  35-44
# 3  ...         EXP          587                      CIB  45-54
# 4  ...        CRIF          602                      EXP  25-34
#
#   submission_of_application        ltv region  security_type status  dtir1
# 0                   to_inst  98.728814  south         direct      1   45.0
# 1                   to_inst        NaN  North         direct      1    NaN
# 2                   to_inst  80.019685  south         direct      0   46.0
# 3                  not_inst  69.376900  North         direct      0   42.0
# 4                  not_inst  91.886544  North         direct      0   39.0
#
# [5 rows x 28 columns]

# %%
#import pickled file
with open('finaldataset.pkl', 'rb') as f:
    data = pickle.load(f)

# Extract the components
X_train = data['X_train']
y_train = data['y_train']
X_test = data['X_test']
y_test = data['y_test']

# %%
with open('finaldataset.pkl', 'rb') as f:
    data = pickle.load(f)
    
print("Class counts in pickle:")
print("y_train:", data['y_train'].value_counts())
print("y_test:", data['y_test'].value_counts())  # or data['y_test'] depending on your pickle structure
# Out:
# Class counts in pickle:
# y_train: status
# 0         85801
# 1         15223
# Name: count, dtype: int64
# y_test: status
# 0         21412
# 1          3845
# Name: count, dtype: int64

# %%
#Ridge Classification, using classiffier due to categorical variable
from sklearn.linear_model import RidgeClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, balanced_accuracy_score

# Scale data using MinMaxScaler (fit only on training set)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Convert to DataFrame to keep column names
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)

# 200 Ridge Classifiers for alphas 1 to 10,000
alphas = np.linspace(1, 10000, 200)
coefs = []
clf = RidgeClassifier()

# Go over each alpha value and fit RidgeClassifier
for a in tqdm(alphas, desc="Fitting Ridge Classifiers"):
    clf.set_params(alpha=a)
    clf.fit(X_train_scaled, y_train)
    coefs.append(clf.coef_[0])  # Store the coefficients of the classifier

# DataFrame of my coefficients
coefs_df = pd.DataFrame(coefs, columns=X_train.columns)

# Top 10 most influential variables at alpha = 10000 
top_10_vars = coefs_df.iloc[-1].abs().nlargest(10).index.tolist()
print("Top 10 most influential variables at alpha = 10000:")
print(top_10_vars)

# Spaghetti plot for the top 10 influential variables 
plt.figure(figsize=(12, 6))
for var in top_10_vars:
    plt.plot(alphas, coefs_df[var], label=var)
plt.xscale('log')
plt.xlabel('Alpha')
plt.ylabel('Coefficient Value')
plt.title('Spaghetti Plot of Top 10 Most Influential Variables')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# Train a RidgeClassifier with alpha = 1.0
clf = RidgeClassifier(alpha=1.0)
clf.fit(X_train_scaled, y_train)
train_pred = clf.predict(X_train_scaled)
test_pred = clf.predict(X_test_scaled)

# Confusion matrices
train_cm = confusion_matrix(y_train, train_pred)
test_cm = confusion_matrix(y_test, test_pred)

# Plot confusion matrices for training and testing sets
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
sns.heatmap(train_cm, annot=True, fmt='d', ax=ax1, cmap='Blues')
ax1.set_title('Training Confusion Matrix')
ax1.set_xlabel('Predicted')
ax1.set_ylabel('Actual')
sns.heatmap(test_cm, annot=True, fmt='d', ax=ax2, cmap='Blues')
ax2.set_title('Test Confusion Matrix')
ax2.set_xlabel('Predicted')
ax2.set_ylabel('Actual')
plt.tight_layout()
plt.show()

# Balanced RidgeClassifier to correct class imbalance
clf_balanced = RidgeClassifier(alpha=1.0, class_weight='balanced')
clf_balanced.fit(X_train_scaled, y_train)
train_pred_bal = clf_balanced.predict(X_train_scaled)
test_pred_bal = clf_balanced.predict(X_test_scaled)

# Confusion matrices for balanced classifier
train_cm_bal = confusion_matrix(y_train, train_pred_bal)
test_cm_bal = confusion_matrix(y_test, test_pred_bal)

# Plot balanced confusion matrices
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
sns.heatmap(train_cm_bal, annot=True, fmt='d', ax=ax1, cmap='Blues')
ax1.set_title('Training Confusion Matrix (Balanced)')
ax1.set_xlabel('Predicted')
ax1.set_ylabel('Actual')
sns.heatmap(test_cm_bal, annot=True, fmt='d', ax=ax2, cmap='Blues')
ax2.set_title('Test Confusion Matrix (Balanced)')
ax2.set_xlabel('Predicted')
ax2.set_ylabel('Actual')
plt.tight_layout()
plt.show()

# Feature importances  with plot reworked for RidgeClassifier
importances = np.abs(clf_balanced.coef_[0])  # RidgeClassifier uses coefficients, not .feature_importances_
feature_names = X_train.columns
feature_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_df = feature_df.sort_values('Importance', ascending=False)  # Sort features by importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_df.head(10))
plt.title('Top 10 Most Important Features (RidgeClassifier)')
plt.xlabel('Absolute Coefficient Value')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()

# Display top 10 featue importances
print("Feature Importances (Top 10):")
print(feature_df.head(10).to_string(index=False))

#getting cv stats
# Define scorers
scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score, zero_division=0),
    'recall': make_scorer(recall_score, zero_division=0),
    'balanced_accuracy': make_scorer(balanced_accuracy_score)
}

# Run 10-fold cross-validation
cv_results = cross_validate(RidgeClassifier(alpha=1.0, class_weight='balanced'),
                            X_train_scaled, y_train,
                            cv=10,
                            scoring=scoring,
                            return_train_score=False)

# Print results
print("\nCV Stats:")
for metric in scoring.keys():
    mean_val = cv_results[f'test_{metric}'].mean()
    std_val = cv_results[f'test_{metric}'].std()
    print(f"{metric.replace('_', ' ').title()} - CV Avg: {mean_val:.3f}, Std: {std_val:.3f}")

# Interpretation of CV Stats:
# Accuracy - CV Avg: 0.684, Std: 0.004
# The model correctly predicted 68.4% of all loan cases across folds.
#  Accuracy can be misleading with imbalanced data such as this dataset

# Precision - CV Avg: 0.26.8, Std: 0.004
# When the model predicts a default (class 1), it is correct ~26.8% of the time.
# About 2 out of 3 default predictions are incorrect/ false positives

# Recall - CV Avg: 0.631, Std: 0.014
# Of all actual defaults, the model correctly catches 63.1% on average.

# Balanced Accuracy - CV Avg: 0.663, Std: 0.006
#A balanced accuracy of 63.3% suggests the model performs reasonably across both groups.
# Out:
# Fitting Ridge Classifiers:   0%|          | 0/200 [00:00<?, ?it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   0%|          | 1/200 [00:00<01:55,  1.72it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   1%|          | 2/200 [00:01<01:42,  1.93it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   2%|▏         | 3/200 [00:01<01:17,  2.55it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   2%|▏         | 4/200 [00:01<01:06,  2.97it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   2%|▎         | 5/200 [00:01<01:03,  3.07it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   3%|▎         | 6/200 [00:02<00:56,  3.44it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   4%|▎         | 7/200 [00:02<00:50,  3.81it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   4%|▍         | 8/200 [00:02<00:49,  3.87it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   4%|▍         | 9/200 [00:02<00:47,  4.00it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   5%|▌         | 10/200 [00:02<00:44,  4.24it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   6%|▌         | 11/200 [00:03<00:41,  4.59it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   6%|▌         | 12/200 [00:03<00:43,  4.30it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   6%|▋         | 13/200 [00:03<00:43,  4.34it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   7%|▋         | 14/200 [00:03<00:45,  4.09it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   8%|▊         | 15/200 [00:04<00:41,  4.41it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   8%|▊         | 16/200 [00:04<00:39,  4.64it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   8%|▊         | 17/200 [00:04<00:41,  4.37it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   9%|▉         | 18/200 [00:04<00:40,  4.49it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  10%|▉         | 19/200 [00:04<00:37,  4.86it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  10%|█         | 20/200 [00:05<00:36,  4.93it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  10%|█         | 21/200 [00:05<00:39,  4.54it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  11%|█         | 22/200 [00:05<00:38,  4.58it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  12%|█▏        | 23/200 [00:05<00:37,  4.78it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  12%|█▏        | 24/200 [00:05<00:36,  4.88it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  12%|█▎        | 25/200 [00:06<00:36,  4.84it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  13%|█▎        | 26/200 [00:06<00:35,  4.84it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  14%|█▎        | 27/200 [00:06<00:33,  5.18it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  14%|█▍        | 28/200 [00:06<00:32,  5.25it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  14%|█▍        | 29/200 [00:06<00:32,  5.20it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  15%|█▌        | 30/200 [00:07<00:33,  5.15it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  16%|█▌        | 31/200 [00:07<00:34,  4.88it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  16%|█▌        | 32/200 [00:07<00:32,  5.15it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  16%|█▋        | 33/200 [00:07<00:31,  5.32it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  17%|█▋        | 34/200 [00:07<00:31,  5.24it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  18%|█▊        | 35/200 [00:08<00:31,  5.22it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  18%|█▊        | 36/200 [00:08<00:30,  5.36it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  18%|█▊        | 37/200 [00:08<00:31,  5.20it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  19%|█▉        | 38/200 [00:08<00:35,  4.55it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  20%|█▉        | 39/200 [00:09<00:40,  3.93it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  20%|██        | 40/200 [00:09<00:37,  4.26it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  20%|██        | 41/200 [00:09<00:35,  4.43it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  21%|██        | 42/200 [00:09<00:32,  4.79it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  22%|██▏       | 43/200 [00:09<00:32,  4.84it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  22%|██▏       | 44/200 [00:10<00:32,  4.84it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  22%|██▎       | 45/200 [00:10<00:30,  5.02it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  23%|██▎       | 46/200 [00:10<00:31,  4.90it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  24%|██▎       | 47/200 [00:10<00:29,  5.19it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  24%|██▍       | 48/200 [00:10<00:28,  5.26it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  24%|██▍       | 49/200 [00:11<00:29,  5.18it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  25%|██▌       | 50/200 [00:11<00:29,  5.07it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  26%|██▌       | 51/200 [00:11<00:28,  5.21it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  26%|██▌       | 52/200 [00:11<00:28,  5.27it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  26%|██▋       | 53/200 [00:11<00:28,  5.24it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  27%|██▋       | 54/200 [00:11<00:27,  5.33it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  28%|██▊       | 55/200 [00:12<00:45,  3.19it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  28%|██▊       | 56/200 [00:12<00:47,  3.06it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  28%|██▊       | 57/200 [00:13<00:46,  3.09it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  29%|██▉       | 58/200 [00:13<00:40,  3.51it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  30%|██▉       | 59/200 [00:13<00:36,  3.88it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  30%|███       | 60/200 [00:13<00:34,  4.11it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  30%|███       | 61/200 [00:14<00:30,  4.58it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  31%|███       | 62/200 [00:14<00:28,  4.80it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  32%|███▏      | 63/200 [00:14<00:28,  4.73it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  32%|███▏      | 64/200 [00:14<00:28,  4.81it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  32%|███▎      | 65/200 [00:14<00:26,  5.03it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  33%|███▎      | 66/200 [00:14<00:26,  5.14it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  34%|███▎      | 67/200 [00:15<00:41,  3.21it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  34%|███▍      | 68/200 [00:15<00:38,  3.44it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  34%|███▍      | 69/200 [00:16<00:36,  3.60it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  35%|███▌      | 70/200 [00:16<00:31,  4.10it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  36%|███▌      | 71/200 [00:16<00:29,  4.37it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  36%|███▌      | 72/200 [00:16<00:26,  4.76it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  36%|███▋      | 73/200 [00:16<00:25,  4.94it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  37%|███▋      | 74/200 [00:16<00:25,  4.92it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  38%|███▊      | 75/200 [00:17<00:33,  3.71it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  38%|███▊      | 76/200 [00:17<00:31,  3.93it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  38%|███▊      | 77/200 [00:17<00:31,  3.91it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  39%|███▉      | 78/200 [00:18<00:27,  4.45it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  40%|███▉      | 79/200 [00:18<00:25,  4.72it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  40%|████      | 80/200 [00:18<00:25,  4.66it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  40%|████      | 81/200 [00:18<00:23,  5.05it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  41%|████      | 82/200 [00:18<00:25,  4.71it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  42%|████▏     | 83/200 [00:19<00:28,  4.12it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  42%|████▏     | 84/200 [00:19<00:28,  4.01it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  42%|████▎     | 85/200 [00:19<00:33,  3.43it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  43%|████▎     | 86/200 [00:19<00:28,  4.01it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  44%|████▎     | 87/200 [00:20<00:25,  4.45it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  44%|████▍     | 88/200 [00:20<00:24,  4.62it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  44%|████▍     | 89/200 [00:20<00:22,  4.98it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  45%|████▌     | 90/200 [00:20<00:21,  5.15it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  46%|████▌     | 91/200 [00:20<00:21,  5.17it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  46%|████▌     | 92/200 [00:21<00:20,  5.22it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  46%|████▋     | 93/200 [00:21<00:20,  5.23it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  47%|████▋     | 94/200 [00:21<00:21,  5.03it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  48%|████▊     | 95/200 [00:21<00:19,  5.30it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  48%|████▊     | 96/200 [00:21<00:19,  5.27it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  48%|████▊     | 97/200 [00:21<00:19,  5.21it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  49%|████▉     | 98/200 [00:22<00:19,  5.14it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  50%|████▉     | 99/200 [00:22<00:31,  3.19it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  50%|█████     | 100/200 [00:23<00:28,  3.46it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  50%|█████     | 101/200 [00:23<00:25,  3.92it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  51%|█████     | 102/200 [00:23<00:23,  4.16it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  52%|█████▏    | 103/200 [00:23<00:21,  4.50it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  52%|█████▏    | 104/200 [00:23<00:19,  4.80it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  52%|█████▎    | 105/200 [00:24<00:22,  4.25it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  53%|█████▎    | 106/200 [00:24<00:20,  4.66it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  54%|█████▎    | 107/200 [00:24<00:20,  4.62it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  54%|█████▍    | 108/200 [00:24<00:18,  4.97it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  55%|█████▍    | 109/200 [00:24<00:17,  5.11it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  55%|█████▌    | 110/200 [00:24<00:17,  5.05it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  56%|█████▌    | 111/200 [00:25<00:17,  5.01it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  56%|█████▌    | 112/200 [00:25<00:17,  5.13it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  56%|█████▋    | 113/200 [00:25<00:21,  4.04it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  57%|█████▋    | 114/200 [00:25<00:19,  4.38it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  57%|█████▊    | 115/200 [00:26<00:18,  4.67it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  58%|█████▊    | 116/200 [00:26<00:19,  4.37it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  58%|█████▊    | 117/200 [00:26<00:17,  4.66it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  59%|█████▉    | 118/200 [00:26<00:16,  4.87it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  60%|█████▉    | 119/200 [00:26<00:15,  5.09it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  60%|██████    | 120/200 [00:27<00:15,  5.18it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  60%|██████    | 121/200 [00:27<00:15,  5.23it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  61%|██████    | 122/200 [00:27<00:15,  5.03it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  62%|██████▏   | 123/200 [00:27<00:14,  5.39it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  62%|██████▏   | 124/200 [00:27<00:15,  4.75it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  62%|██████▎   | 125/200 [00:28<00:14,  5.17it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  63%|██████▎   | 126/200 [00:28<00:13,  5.41it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  64%|██████▎   | 127/200 [00:28<00:14,  5.00it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  64%|██████▍   | 128/200 [00:28<00:13,  5.32it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  64%|██████▍   | 129/200 [00:28<00:12,  5.46it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  65%|██████▌   | 130/200 [00:29<00:13,  5.38it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  66%|██████▌   | 131/200 [00:29<00:12,  5.32it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  84%|████████▍ | 169/200 [00:36<00:07,  4.27it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  85%|████████▌ | 170/200 [00:36<00:06,  4.75it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  86%|████████▌ | 171/200 [00:37<00:06,  4.70it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  86%|████████▌ | 172/200 [00:37<00:05,  4.99it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  86%|████████▋ | 173/200 [00:37<00:05,  5.12it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  87%|████████▋ | 174/200 [00:37<00:04,  5.34it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  88%|████████▊ | 175/200 [00:37<00:04,  5.44it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  88%|████████▊ | 176/200 [00:38<00:04,  5.02it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  88%|████████▊ | 177/200 [00:38<00:04,  5.37it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  89%|████████▉ | 178/200 [00:38<00:04,  5.31it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  90%|████████▉ | 179/200 [00:38<00:04,  5.25it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  90%|█████████ | 180/200 [00:38<00:03,  5.42it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  90%|█████████ | 181/200 [00:38<00:03,  4.83it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  91%|█████████ | 182/200 [00:39<00:04,  3.92it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  92%|█████████▏| 183/200 [00:39<00:03,  4.44it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  92%|█████████▏| 184/200 [00:39<00:03,  4.69it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  92%|█████████▎| 185/200 [00:39<00:03,  4.71it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  93%|█████████▎| 186/200 [00:40<00:02,  4.84it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  94%|█████████▎| 187/200 [00:40<00:02,  5.22it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  94%|█████████▍| 188/200 [00:40<00:02,  5.21it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  94%|█████████▍| 189/200 [00:40<00:02,  5.21it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  95%|█████████▌| 190/200 [00:40<00:01,  5.23it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  96%|█████████▌| 191/200 [00:41<00:01,  5.23it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  96%|█████████▌| 192/200 [00:41<00:01,  5.31it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  96%|█████████▋| 193/200 [00:41<00:01,  4.63it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  97%|█████████▋| 194/200 [00:41<00:01,  4.93it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  98%|█████████▊| 195/200 [00:41<00:00,  5.11it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  98%|█████████▊| 196/200 [00:42<00:00,  5.22it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  98%|█████████▊| 197/200 [00:42<00:00,  5.30it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  99%|█████████▉| 198/200 [00:42<00:00,  4.54it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers: 100%|█████████▉| 199/200 [00:42<00:00,  4.77it/s]/opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers: 100%|██████████| 200/200 [00:42<00:00,  4.66it/s]
# Top 10 most influential variables at alpha = 10000:
# ['lump_sum_payment_lpsm', 'lump_sum_payment_not_lpsm', 'neg_ammortization_not_neg', 'neg_ammortization_neg_amm', 'dtir1', 'income', 'submission_of_application_to_inst', 'submission_of_application_not_inst', 'occupancy_type_pr', 'loan_type_type2']
# /opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Feature Importances (Top 10):
#                   Feature  Importance
#                    income    0.760074
#          credit_type_EQUI    0.490007
#                     dtir1    0.457965
#     lump_sum_payment_lpsm    0.434746
# lump_sum_payment_not_lpsm    0.434746
#                       ltv    0.431178
#      construction_type_sb    0.420069
#      construction_type_mh    0.420069
# neg_ammortization_not_neg    0.227625
# neg_ammortization_neg_amm    0.227625
# /opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/anaconda3/envs/misy331_base/lib/python3.13/site-packages/sklearn/linear_model/_ridge.py:1209: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# CV Stats:
# Accuracy - CV Avg: 0.684, Std: 0.004
# Precision - CV Avg: 0.268, Std: 0.004
# Recall - CV Avg: 0.631, Std: 0.014
# Balanced Accuracy - CV Avg: 0.663, Std: 0.006
