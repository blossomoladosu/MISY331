# %%
rs = 1234 
import pandas as pd
import pickle
import statsmodels.api as sm
import numpy as np
from tqdm.notebook import tqdm
tqdm.pandas()

df = pd.read_pickle('dfclean.pkl')
df.head()
# Out:
#   loan_limit             gender approv_in_adv loan_type loan_purpose  \
# 0         cf  Sex Not Available         nopre     type1           p1
# 2         cf               Male           pre     type1           p1
# 3         cf               Male         nopre     type1           p4
# 4         cf              Joint           pre     type1           p1
# 5         cf              Joint           pre     type1           p1
#
#   credit_worthiness business_or_commercial  loan_amount   term  \
# 0                l1                  nob/c       116500  360.0
# 2                l1                  nob/c       406500  360.0
# 3                l1                  nob/c       456500  360.0
# 4                l1                  nob/c       696500  360.0
# 5                l1                  nob/c       706500  360.0
#
#   neg_ammortization  ...   income credit_type credit_score  \
# 0           not_neg  ...   1740.0         EXP          758
# 2           neg_amm  ...   9480.0         EXP          834
# 3           not_neg  ...  11880.0         EXP          587
# 4           not_neg  ...  10440.0        CRIF          602
# 5           not_neg  ...  10080.0         EXP          864
#
#   co-applicant_credit_type    age  submission_of_application        ltv  \
# 0                      CIB  25-34                    to_inst  98.728814
# 2                      CIB  35-44                    to_inst  80.019685
# 3                      CIB  45-54                   not_inst  69.376900
# 4                      EXP  25-34                   not_inst  91.886544
# 5                      EXP  35-44                   not_inst  70.089286
#
#    region status dtir1
# 0   south      1  45.0
# 2   south      0  46.0
# 3   North      0  42.0
# 4   North      0  39.0
# 5   North      0  40.0
#
# [5 rows x 25 columns]

# %%
#import pickled file
with open('finaldataset.pkl', 'rb') as f:
    data = pickle.load(f)

# Extract the components
X_train = data['X_train']
y_train = data['y_train']
X_test = data['X_test']
y_test = data['y_test']

# %%
with open('finaldataset.pkl', 'rb') as f:
    data = pickle.load(f)
    
print("Class counts in pickle:")
print("y_train:", data['y_train'].value_counts())
print("y_test:", data['y_test'].value_counts())  # or data['y_test'] depending on your pickle structure
# Out:
# Class counts in pickle:
# y_train: status
# 0         85801
# 1         15223
# Name: count, dtype: int64
# y_test: status
# 0         21412
# 1          3845
# Name: count, dtype: int64

# %%
#Ridge Classification, using classiffier due to categorical variable
from sklearn.linear_model import RidgeClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, balanced_accuracy_score

# Scale data using MinMaxScaler (fit only on training set)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Convert to DataFrame to keep column names
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)

# 200 Ridge Classifiers for alphas 1 to 10,000
alphas = np.linspace(1, 10000, 200)
coefs = []
clf = RidgeClassifier()

# Go over each alpha value and fit RidgeClassifier
for a in tqdm(alphas, desc="Fitting Ridge Classifiers"):
    clf.set_params(alpha=a)
    clf.fit(X_train_scaled, y_train)
    coefs.append(clf.coef_[0])  # Store the coefficients of the classifier
# Out:
# Fitting Ridge Classifiers:   0%|          | 0/200 [00:00<?, ?it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   0%|          | 1/200 [00:00<00:23,  8.57it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   1%|          | 2/200 [00:00<00:21,  9.17it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   2%|▏         | 3/200 [00:00<00:21,  9.31it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   2%|▎         | 5/200 [00:00<00:19,  9.78it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:   3%|▎         | 6/200 [00:00<00:20,  9.67it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:
/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  80%|████████  | 160/200 [00:17<00:04,  9.46it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  80%|████████  | 161/200 [00:17<00:04,  9.48it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  81%|████████  | 162/200 [00:17<00:03,  9.50it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  82%|████████▏ | 163/200 [00:17<00:03,  9.27it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  82%|████████▏ | 164/200 [00:17<00:03,  9.30it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  82%|████████▎ | 165/200 [00:17<00:03,  9.27it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  83%|████████▎ | 166/200 [00:17<00:03,  9.38it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  84%|████████▎ | 167/200 [00:17<00:03,  9.43it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  84%|████████▍ | 168/200 [00:17<00:03,  9.56it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  84%|████████▍ | 169/200 [00:17<00:03,  9.54it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  85%|████████▌ | 170/200 [00:18<00:03,  9.51it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  86%|████████▌ | 171/200 [00:18<00:03,  8.38it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  86%|████████▌ | 172/200 [00:18<00:03,  8.61it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  86%|████████▋ | 173/200 [00:18<00:03,  8.89it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  87%|████████▋ | 174/200 [00:18<00:02,  9.09it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  88%|████████▊ | 175/200 [00:18<00:02,  9.01it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  88%|████████▊ | 176/200 [00:18<00:02,  9.10it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  88%|████████▊ | 177/200 [00:18<00:02,  9.34it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  89%|████████▉ | 178/200 [00:18<00:02,  9.41it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  90%|████████▉ | 179/200 [00:19<00:02,  9.47it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  90%|█████████ | 180/200 [00:19<00:02,  9.51it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  90%|█████████ | 181/200 [00:19<00:02,  9.35it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  91%|█████████ | 182/200 [00:19<00:01,  9.42it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  92%|█████████▏| 184/200 [00:19<00:01,  9.94it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  93%|█████████▎| 186/200 [00:19<00:01,  9.99it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  94%|█████████▍| 188/200 [00:19<00:01,  9.85it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  95%|█████████▌| 190/200 [00:20<00:01,  9.85it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  96%|█████████▌| 192/200 [00:20<00:00,  9.00it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  97%|█████████▋| 194/200 [00:20<00:00,  9.47it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  98%|█████████▊| 196/200 [00:20<00:00,  9.65it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  98%|█████████▊| 197/200 [00:20<00:00,  9.65it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers:  99%|█████████▉| 198/200 [00:21<00:00,  9.62it/s]c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting Ridge Classifiers: 100%|██████████| 200/200 [00:21<00:00,  9.42it/s]

# %%
# Train a RidgeClassifier with alpha = 1.0
clf = RidgeClassifier(alpha=1.0)
clf.fit(X_train_scaled, y_train)
train_pred = clf.predict(X_train_scaled)
test_pred = clf.predict(X_test_scaled)

# Confusion matrices
train_cm = confusion_matrix(y_train, train_pred)
test_cm = confusion_matrix(y_test, test_pred)

# Plot confusion matrices for training and testing sets
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
sns.heatmap(train_cm, annot=True, fmt='d', ax=ax1, cmap='Blues')
ax1.set_title('Training Confusion Matrix')
ax1.set_xlabel('Predicted')
ax1.set_ylabel('Actual')
sns.heatmap(test_cm, annot=True, fmt='d', ax=ax2, cmap='Blues')
ax2.set_title('Test Confusion Matrix')
ax2.set_xlabel('Predicted')
ax2.set_ylabel('Actual')
plt.tight_layout()
plt.show()

# Balanced RidgeClassifier to correct class imbalance
clf_balanced = RidgeClassifier(alpha=1.0, class_weight='balanced')
clf_balanced.fit(X_train_scaled, y_train)
train_pred_bal = clf_balanced.predict(X_train_scaled)
test_pred_bal = clf_balanced.predict(X_test_scaled)

# Confusion matrices for balanced classifier
train_cm_bal = confusion_matrix(y_train, train_pred_bal)
test_cm_bal = confusion_matrix(y_test, test_pred_bal)

# Plot balanced confusion matrices
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))
sns.heatmap(train_cm_bal, annot=True, fmt='d', ax=ax1, cmap='Blues')
ax1.set_title('Training Confusion Matrix (Balanced)')
ax1.set_xlabel('Predicted')
ax1.set_ylabel('Actual')
sns.heatmap(test_cm_bal, annot=True, fmt='d', ax=ax2, cmap='Blues')
ax2.set_title('Test Confusion Matrix (Balanced)')
ax2.set_xlabel('Predicted')
ax2.set_ylabel('Actual')
plt.tight_layout()
plt.show()

# Feature importances  with plot reworked for RidgeClassifier
importances = np.abs(clf_balanced.coef_[0])  # RidgeClassifier uses coefficients, not .feature_importances_
feature_names = X_train.columns
feature_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})
feature_df = feature_df.sort_values('Importance', ascending=False)  # Sort features by importance
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_df.head(10))
plt.title('Top 10 Most Important Features (RidgeClassifier)')
plt.xlabel('Absolute Coefficient Value')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()

# Display top 10 featue importances
print("Feature Importances (Top 10):")
print(feature_df.head(10).to_string(index=False))

#getting cv stats
# Define scorers
scoring = {
    'accuracy': make_scorer(accuracy_score),
    'precision': make_scorer(precision_score, zero_division=0),
    'recall': make_scorer(recall_score, zero_division=0),
    'balanced_accuracy': make_scorer(balanced_accuracy_score)
}

# Run 10-fold cross-validation
cv_results = cross_validate(RidgeClassifier(alpha=1.0, class_weight='balanced'),
                            X_train_scaled, y_train,
                            cv=10,
                            scoring=scoring,
                            return_train_score=False)
# Out:
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Feature Importances (Top 10):
#        Feature  Importance
#    loan_amount    0.188141
#           term    0.188141
#         income    0.188141
#   credit_score    0.188141
#            ltv    0.188141
#          dtir1    0.188141
#  loan_limit_cf    0.188141
# loan_limit_ncf    0.188141
#  gender_Female    0.188141
#   gender_Joint    0.188141
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\micah\miniconda3\envs\misy331_base\Lib\site-packages\sklearn\linear_model\_ridge.py:1307: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Print results
print("\nCV Stats:")
for metric in scoring.keys():
    mean_val = cv_results[f'test_{metric}'].mean()
    std_val = cv_results[f'test_{metric}'].std()
    print(f"{metric.replace('_', ' ').title()} - CV Avg: {mean_val:.3f}, Std: {std_val:.3f}")
# Out:
# CV Stats:
# Accuracy - CV Avg: 0.684, Std: 0.004
# Precision - CV Avg: 0.268, Std: 0.004
# Recall - CV Avg: 0.631, Std: 0.014
# Balanced Accuracy - CV Avg: 0.663, Std: 0.006

# %%
# Interpretation of CV Stats:
# Accuracy - CV Avg: 0.684, Std: 0.004
# The model correctly predicted 68.4% of all loan cases across folds.
#  Accuracy can be misleading with imbalanced data such as this dataset

# Precision - CV Avg: 0.26.8, Std: 0.004
# When the model predicts a default (class 1), it is correct ~26.8% of the time.
# About 2 out of 3 default predictions are incorrect/ false positives

# Recall - CV Avg: 0.631, Std: 0.014
# Of all actual defaults, the model correctly catches 63.1% on average.

# Balanced Accuracy - CV Avg: 0.663, Std: 0.006
#A balanced accuracy of 63.3% suggests the model performs reasonably across both groups.
